# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekJain121/python-projects/blob/main/case_study_Covid_19_Data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# import the dataset
dataset = pd.read_csv("/content/gdrive/MyDrive/dataset/covid19_Confirmed_dataset.csv")

# %%
dataset.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
dataset.shape
# Out:
# (266, 104)

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
# ...

# %%
dataset.shape
# Out:
# (266, 102)

# %%
dataset.head(5)
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
# aggregrate the rows by the country
corona_dataset_aggregated = dataset.groupby("Country/Region").sum()
# Out:
# <ipython-input-11-0ce555acec4f>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   corona_dataset_aggregated = dataset.groupby("Country/Region").sum()

# %%
# visulize data related to country
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["India"].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc["China"][:3].plot

# %%
#calculate the first derivative of the curve
corona_dataset_aggregated.loc['China'].diff().plot()
# Out:
# <Axes: >

# %%
# maximum infection rate
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc["India"].diff().max()
# Out:
# 1893.0

# %%
 countries = list(corona_dataset_aggregated.index)
 max_infection_rates = []
 for c in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
 corona_dataset_aggregated['max infection rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                     Lat     Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan     33.0000  65.0000        0        0        0        0        0
# Albania         41.1533  20.1683        0        0        0        0        0
# Algeria         28.0339   1.6596        0        0        0        0        0
# Andorra         42.5063   1.5218        0        0        0        0        0
# Angola         -11.2027  17.8739        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
#create a new dataframe
corona_data = pd.DataFrame(corona_dataset_aggregated["max infection rate"])

# %%
corona_data
# Out:
#                     max infection rate
# Country/Region
# Afghanistan                 232.000000
# Albania                      34.000000
# Algeria                     199.000000
# Andorra                      43.000000
# Angola                       29.076600
# ...                                ...
# West Bank and Gaza           66.000000
# Western Sahara               12.885800
# Yemen                        32.963661
# Zambia                       43.700000
# Zimbabwe                     50.000000
#
# [187 rows x 1 columns]

# %%
dataset.tail()
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# 261        0        0        0        0        0  ...        6        6
# 262        0        0        0        0        0  ...        4        4
# 263        0        0        0        0        0  ...        1        1
# 264        0        0        0        0        0  ...        0        0
# 265        0        0        0        0        0  ...        0        0
#
#      4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
# importing the dataset 2
happiness_report = pd.read_csv("/content/worldwide_happiness_report.csv")

happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#drop useless columns
useless_cols= ["overall rank" , "score" , "Generosity", "Perceptions of corruption"]

# %%
happiness_report.head()
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                       1  7.769           1.340           1.587
# Denmark                       2  7.600           1.383           1.573
# Norway                        3  7.554           1.488           1.582
# Iceland                       4  7.494           1.380           1.624
# Netherlands                   5  7.488           1.396           1.522
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Finland                              0.986                         0.596
# Denmark                              0.996                         0.592
# Norway                               1.028                         0.603
# Iceland                              1.026                         0.591
# Netherlands                          0.999                         0.557
#
#                    Generosity  Perceptions of corruption
# ...

# %%
#joining the dataset
corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report.shape
# Out:
# (156, 8)

# %%
data = corona_data.join(happiness_report , how = "inner")
data
# Out:
#              max infection rate  Overall rank  Score  GDP per capita  \
# Afghanistan          232.000000           154  3.203           0.350
# Albania               34.000000           107  4.719           0.947
# Algeria              199.000000            88  5.211           1.002
# Argentina            291.000000            47  6.086           1.092
# Armenia              134.000000           116  4.559           0.850
# ...                         ...           ...    ...             ...
# Venezuela             66.589700           108  4.707           0.960
# Vietnam               92.000000            94  5.175           0.741
# Yemen                 32.963661           151  3.380           0.287
# Zambia                43.700000           138  4.107           0.578
# Zimbabwe              50.000000           146  3.663           0.366
#
#              Social support  Healthy life expectancy  \
# Afghanistan           0.517                    0.361
# ...

# %%
data.corr()
# Out:
#                               max infection rate  Overall rank     Score  \
# max infection rate                      1.000000     -0.247073  0.231363
# Overall rank                           -0.247073      1.000000 -0.988972
# Score                                   0.231363     -0.988972  1.000000
# GDP per capita                          0.251203     -0.802204  0.793847
# Social support                          0.194233     -0.780955  0.788591
# Healthy life expectancy                 0.291478     -0.804753  0.799893
# Freedom to make life choices            0.080998     -0.570490  0.587007
# Generosity                             -0.110332     -0.063107  0.090420
# Perceptions of corruption               0.101891     -0.389360  0.420437
#
#                               GDP per capita  Social support  \
# max infection rate                  0.251203        0.194233
# Overall rank                       -0.802204       -0.780955
# ...

# %%
data
# Out:
#              max infection rate  Overall rank  Score  GDP per capita  \
# Afghanistan          232.000000           154  3.203           0.350
# Albania               34.000000           107  4.719           0.947
# Algeria              199.000000            88  5.211           1.002
# Argentina            291.000000            47  6.086           1.092
# Armenia              134.000000           116  4.559           0.850
# ...                         ...           ...    ...             ...
# Venezuela             66.589700           108  4.707           0.960
# Vietnam               92.000000            94  5.175           0.741
# Yemen                 32.963661           151  3.380           0.287
# Zambia                43.700000           138  4.107           0.578
# Zimbabwe              50.000000           146  3.663           0.366
#
#              Social support  Healthy life expectancy  \
# Afghanistan           0.517                    0.361
# ...

# %%
#visulation
x=data["GDP per capita"]
y = data["max infection rate"]
# Import the required libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Create the scatter plot
sns.scatterplot(x)
sns.scatterplot(y)
# Out:
# <Axes: ylabel='GDP per capita'>

# %%
# x-coordinates of left sides of bars
left = [1, 2, 3, 4, 5]

# heights of bars
height = [10, 24, 36, 40, 5]

# labels for bars
tick_label = ['one', 'two', 'three', 'four', 'five']

# plotting a bar chart
plt.bar(left, height, tick_label = tick_label,
        width = 0.8, color = ['red', 'green'])

# naming the x-axis
plt.xlabel('x - axis')
# naming the y-axis
plt.ylabel('y - axis')
# plot title
plt.title('My bar chart!')

# function to show the plot
plt.show()

# %%
x= data["Social support"]
y = data["max infection rate"]
# Import the required libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create the scatter plot with logarithmic y-values
plt.scatter(x, np.log(y))

# Display the plot
plt.show()

# %%
x= data["Healthy life expectancy"]
y= data["max infection rate"]
plt.scatter(x,np.log(y))

# %%
happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...
